# %%
# !pip install --no-input sklearn
# Out:
# Requirement already satisfied: sklearn in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (from sklearn) (1.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: numpy>=1.14.6 in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.2)
# Requirement already satisfied: joblib>=0.11 in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/maxim/opt/anaconda3/envs/random-forest-fennel-encounter-notes/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)

# %%
pip install --no-input sklearn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting scikit-learn
#   Using cached scikit_learn-1.0-cp39-cp39-macosx_10_13_x86_64.whl (8.0 MB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.2)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed joblib-1.0.1 scikit-learn-1.0 sklearn-0.0 threadpoolctl-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package             Version
# ------------------- ---------
# appnope             0.1.2
# argon2-cffi         21.1.0
# attrdict            2.0.0
# attrs               21.2.0
# backcall            0.2.0
# beautifulsoup4      4.9.3
# bleach              4.1.0
# certifi             2021.5.30
# cffi                1.14.6
# chardet             4.0.0
# cycler              0.10.0
# debugpy             1.4.3
# decorator           5.1.0
# defusedxml          0.7.1
# entrypoints         0.3
# idna                2.10
# ipykernel           6.4.1
# ipython             7.28.0
# ipython-genutils    0.2.0
# ipywidgets          7.6.5
# jedi                0.18.0
# Jinja2              2.8
# joblib              1.0.1
# jsonschema          3.2.0
# jupyter             1.0.0
# jupyter-client      7.0.3
# jupyter-console     6.4.0
# jupyter-core        4.8.1
# jupyterlab-pygments 0.1.2
# jupyterlab-widgets  1.0.2
# kiwisolver          1.3.2
# lxml                4.6.3
# MarkupSafe          2.0.1
# matplotlib          3.4.3
# matplotlib-inline   0.1.3
# MechanicalSoup      1.1.0
# mistune             0.8.4
# nbclient            0.5.4
# nbconvert           6.2.0
# nbformat            5.1.3
# nest-asyncio        1.5.1
# notebook            6.4.4
# numpy               1.21.2
# packaging           21.0
# pandas              1.3.3
# pandocfilters       1.5.0
# parso               0.8.2
# patsy               0.5.2
# pexpect             4.8.0
# pickleshare         0.7.5
# Pillow              8.3.2
# pip                 21.2.4
# plotly              5.3.1
# plotly-express      0.4.1
# prometheus-client   0.11.0
# prompt-toolkit      3.0.20
# protobuf            3.17.3
# ptyprocess          0.7.0
# pycparser           2.20
# Pygments            2.10.0
# pyparsing           2.4.7
# pyrsistent          0.18.0
# python-dateutil     2.8.2
# pytz                2021.3
# pyzmq               22.3.0
# qtconsole           5.1.1
# QtPy                1.11.2
# requests            2.25.1
# scikit-learn        1.0
# scipy               1.7.1
# Send2Trash          1.8.0
# setuptools          57.4.0
# six                 1.16.0
# sklearn             0.0
# soupsieve           2.2.1
# statsmodels         0.13.0
# tenacity            8.0.1
# terminado           0.12.1
# testpath            0.5.0
# threadpoolctl       3.0.0
# tornado             6.1
# traitlets           5.1.0
# urllib3             1.26.5
# wcwidth             0.2.5
# webencodings        0.5.1
# wheel               0.37.0
# widgetsnbextension  3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/train.csv", sep=",")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns="Survived"), 
    df["Survived"], 
    test_size=0.25, 
    random_state = 101
)

# %% [markdown]
# ## Challenge :: Build a Baseline Model

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

# %%
m = DummyClassifier(strategy='stratified')
clf = m.fit(X_train, y_train)
y_pred = m.predict(X_test)
y_pred

# %%
m.score(X_test, y_test)

# %%
# score()

# %%
accuracy_score(y_test, y_pred)

# %%
from sklearn.datasets import fetch_california_housing
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import RandomizedSearchCV
# from sklearn.model_selection import train_test_split
# from scipy.stats import randint

# # X, y = fetch_california_housing(return_X_y=True)
# # X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# # define the parameter space that will be searched over
# param_distributions = {'n_estimators': randint(1,5),
#                        'max_depth': randint(5,10)}

# # now create a searchCV object and fit it to the data
# search = RandomizedSearchCV(estimator=RandomForestRegressor(random_state=0),
#                             n_iter=5,
#                             param_distributions=param_distributions,
#                             random_state=0)
# search.fit(X_train, y_train)

# %%
# search.best_params_

# %%
# # the search object now acts like a normal random forest estimator
# # with max_depth=9 and n_estimators=4
# search.score(X_test, y_test)
