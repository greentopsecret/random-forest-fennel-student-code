# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.eventbrite.de/d/germany--berlin/music--events/'
response = requests.get(url)
event_soup = BeautifulSoup(response.text)
class_name = 'eds-event-card__formatted-name--is-clamped eds-event-card__formatted-name--is-clamped-three eds-text-weight--heavy'

# %%
event_titles = re.findall(r'\>(.*?)\<', str(event_soup.find_all(class_= class_name)))
event_titles
# Out:
# ['Hardcore High Halloween Party',
#  ', ',
#  'Hardcore High Halloween Party',
#  ', ',
#  'Berlin Tekk pres. Die Gebrüder Brett, Leigh Johnson, TSBiN and more',
#  ', ',
#  'Berlin Tekk pres. Die Gebrüder Brett, Leigh Johnson, TSBiN and more',
#  ', ',
#  'King Kong Kicks • Indie Pop Party • Badehaus Berlin',
#  ', ',
#  'King Kong Kicks • Indie Pop Party • Badehaus Berlin',
#  ', ',
#  'Kiezsalon w/ Anna von Hausswolff at Kaiser-Wilhelm-Gedächtniskirche',
#  ', ',
#  'Kiezsalon w/ Anna von Hausswolff at Kaiser-Wilhelm-Gedächtniskirche',
#  ', ',
#  'HALLOWEEN K-POP PARTY - Freitag, 29.10.2021 @Club ASeven by Aigoo Music',
#  ', ',
#  'HALLOWEEN K-POP PARTY - Freitag, 29.10.2021 @Club ASeven by Aigoo Music',
#  ', ',
#  '✦✦✦ Berlin Techno w/ Torsten Kanzler ✦✦✦',
#  ', ',
#  '✦✦✦ Berlin Techno w/ Torsten Kanzler ✦✦✦',
#  ', ',
#  'Most Wanted: Music 2021',
#  ', ',
#  'Most Wanted: Music 2021',
#  ', ',
#  'Kiezsalon w/ Mabe Fratti and Lea Bertucci at Musikbrauerei',
#  ', ',
#  'Kiezsalon w/ Mabe Fratti and Lea Bertucci at Musikbrauerei',
#  ', ',
#  'Move iT! - die 90er Party',
#  ', ',
#  'Move iT! - die 90er Party',
#  ', ',
#  'Fisch sucht Fahrrad-Party in Berlin | 22. Oktober 2021',
#  ', ',
#  'Fisch sucht Fahrrad-Party in Berlin | 22. Oktober 2021',
#  ', ',
#  'Birgit´s Halloween Bambule (House, Techno, 80s 90s, Pop &amp; Hip Hop)',
#  ', ',
#  'Birgit´s Halloween Bambule (House, Techno, 80s 90s, Pop &amp; Hip Hop)',
#  ', ',
#  'HOLI FESTIVAL OF COLOURS BERLIN 2021',
#  ', ',
#  'HOLI FESTIVAL OF COLOURS BERLIN 2021',
#  ', ',
#  'GOA TRIBE - MAYDAY MAYDAY',
#  ', ',
#  'GOA TRIBE - MAYDAY MAYDAY',
#  ', ',
#  'Die XXL 90er Party / Mütze Katze DJ Team',
#  ', ',
#  'Die XXL 90er Party / Mütze Katze DJ Team',
#  ', ',
#  'BERLIN INDIE NIGHT im Astra Kulturhaus',
#  ', ',
#  'BERLIN INDIE NIGHT im Astra Kulturhaus',
#  ', ',
#  'Canto General (Der große Gesang)',
#  ', ',
#  'Canto General (Der große Gesang)',
#  ', ',
#  'VDSIS-BERLIN LIVE KONZERT',
#  ', ',
#  'VDSIS-BERLIN LIVE KONZERT',
#  ', ',
#  'Mega 90er Rave XXL ARENA Verschoben',
#  ', ',
#  'Mega 90er Rave XXL ARENA Verschoben',
#  ', ',
#  'The Weight of Light',
#  ', ',
#  'The Weight of Light',
#  ', ',
#  'TWIN TRIBES',
#  ', ',
#  'TWIN TRIBES']

# %%
event_titles = list(dict.fromkeys(event_titles))
event_titles
# Out:
# ['Hardcore High Halloween Party',
#  ', ',
#  'Berlin Tekk pres. Die Gebrüder Brett, Leigh Johnson, TSBiN and more',
#  'King Kong Kicks • Indie Pop Party • Badehaus Berlin',
#  'Kiezsalon w/ Anna von Hausswolff at Kaiser-Wilhelm-Gedächtniskirche',
#  'HALLOWEEN K-POP PARTY - Freitag, 29.10.2021 @Club ASeven by Aigoo Music',
#  '✦✦✦ Berlin Techno w/ Torsten Kanzler ✦✦✦',
#  'Most Wanted: Music 2021',
#  'Kiezsalon w/ Mabe Fratti and Lea Bertucci at Musikbrauerei',
#  'Move iT! - die 90er Party',
#  'Fisch sucht Fahrrad-Party in Berlin | 22. Oktober 2021',
#  'Birgit´s Halloween Bambule (House, Techno, 80s 90s, Pop &amp; Hip Hop)',
#  'HOLI FESTIVAL OF COLOURS BERLIN 2021',
#  'GOA TRIBE - MAYDAY MAYDAY',
#  'Die XXL 90er Party / Mütze Katze DJ Team',
#  'BERLIN INDIE NIGHT im Astra Kulturhaus',
#  'Canto General (Der große Gesang)',
#  'VDSIS-BERLIN LIVE KONZERT',
#  'Mega 90er Rave XXL ARENA Verschoben',
#  'The Weight of Light',
#  'TWIN TRIBES']

# %%
event_titles.pop(1)
event_titles
# Out:
# ['Hardcore High Halloween Party',
#  'Berlin Tekk pres. Die Gebrüder Brett, Leigh Johnson, TSBiN and more',
#  'King Kong Kicks • Indie Pop Party • Badehaus Berlin',
#  'Kiezsalon w/ Anna von Hausswolff at Kaiser-Wilhelm-Gedächtniskirche',
#  'HALLOWEEN K-POP PARTY - Freitag, 29.10.2021 @Club ASeven by Aigoo Music',
#  '✦✦✦ Berlin Techno w/ Torsten Kanzler ✦✦✦',
#  'Most Wanted: Music 2021',
#  'Kiezsalon w/ Mabe Fratti and Lea Bertucci at Musikbrauerei',
#  'Move iT! - die 90er Party',
#  'Fisch sucht Fahrrad-Party in Berlin | 22. Oktober 2021',
#  'Birgit´s Halloween Bambule (House, Techno, 80s 90s, Pop &amp; Hip Hop)',
#  'HOLI FESTIVAL OF COLOURS BERLIN 2021',
#  'GOA TRIBE - MAYDAY MAYDAY',
#  'Die XXL 90er Party / Mütze Katze DJ Team',
#  'BERLIN INDIE NIGHT im Astra Kulturhaus',
#  'Canto General (Der große Gesang)',
#  'VDSIS-BERLIN LIVE KONZERT',
#  'Mega 90er Rave XXL ARENA Verschoben',
#  'The Weight of Light',
#  'TWIN TRIBES']

# %%
for i in range(2,15,1):
    url = 'https://www.eventbrite.de/d/germany--berlin/music--events/?page={}'.format(i)
    response = requests.get(url)
    event_soup = BeautifulSoup(response.text)
    event_titles_temp = re.findall(r'\>(.*?)\<', str(event_soup.find_all(class_= class_name)))
    event_titles_temp = list(dict.fromkeys(event_titles_temp))
    event_titles_temp.pop(1)
    event_titles.append(event_titles_temp)
    
event_titles
# Out:
# ['Hardcore High Halloween Party',
#  ', ',
#  'Berlin Tekk pres. Die Gebrüder Brett, Leigh Johnson, TSBiN and more',
#  'King Kong Kicks • Indie Pop Party • Badehaus Berlin',
#  'Kiezsalon w/ Anna von Hausswolff at Kaiser-Wilhelm-Gedächtniskirche',
#  'HALLOWEEN K-POP PARTY - Freitag, 29.10.2021 @Club ASeven by Aigoo Music',
#  '✦✦✦ Berlin Techno w/ Torsten Kanzler ✦✦✦',
#  'Most Wanted: Music 2021',
#  'Kiezsalon w/ Mabe Fratti and Lea Bertucci at Musikbrauerei',
#  'Move iT! - die 90er Party',
#  'Fisch sucht Fahrrad-Party in Berlin | 22. Oktober 2021',
#  'Birgit´s Halloween Bambule (House, Techno, 80s 90s, Pop &amp; Hip Hop)',
#  'HOLI FESTIVAL OF COLOURS BERLIN 2021',
#  'GOA TRIBE - MAYDAY MAYDAY',
#  'Die XXL 90er Party / Mütze Katze DJ Team',
#  'BERLIN INDIE NIGHT im Astra Kulturhaus',
#  'Canto General (Der große Gesang)',
#  'VDSIS-BERLIN LIVE KONZERT',
#  'Mega 90er Rave XXL ARENA Verschoben',
#  'The Weight of Light',
#  'TWIN TRIBES',
#  ["Kilkelly's Halloween Cabaret: Feat. Mimi Oh La La!",
#   'BURNA BOY EDITION I Fr. 22.10. I The Liberate Berlin',
#   'AbunDance special // Samhain Ceremony for Women',
#   "MONOM AUTUMN SERIES Presents: Marvin's Dream",
#   'Proxima w/ Freestyler, MDSM, Sabu! and Zips',
#   'BLOW UP - MaHalla presents a Music Ashram Halloween Show',
#   'BERLIN BOOM ORCHESTRA',
#   'OG BUNKER RAVE 08 (Nur geimpft &amp; genesen / Only vaccinated &amp; recovered)',
#   'Ma Baker Party im Silverwings ✪ 80er 90er 2000er RnB House Charts Disco',
#   'THE VELVET CREEPERS',
#   'ESBEN AND THE WITCH • Berlin Urban Spree',
#   'Heimat, Herz, Orte w/ Stella Chiweshe @ Galerie Bernau',
#   'Melvin Touché + The Tom-Toms',
#   'OG Psytrance x DnB Rave 05 (2G)',
#   'Hops &amp; Hopsi - Der große Hopsini',
#   'Jaimie Branch- fly or die II: bird dogs of paradise',
#   '"For Those Of Us" Afterburner (Audrey Chen + Doron Sadja)',
#   "You'll Have Had Your Jags?",
#   'The Fugitives (CAN) - Folk',
#   'Anmeldung für Jazzkonzert - Quintet Ingi Bjarni Skúlason'],
#  ['LASS ZOCKEN • INDIE vs HIPHOP • RE-OPENING • DIE 1. PARTY IM LIDO',
#   'RENT - The Musical',
#   'Sybille Mahni &amp; Ikuko Odai // Horn &amp; Klavier',
#   'THE FRANZGANG - ROCK, BLUES and MORE - Definitive Cover Versions',
#   'Juan Carlos Garcia „el Lobo de la Salsa“',
#   'Collage - Forum für frühe Musik | A Dieu Fortune - Abschied von Judy†',
#   'Maire Breatnach &amp; Thomas Loefke - Celtic Fiddle, Harp &amp; Song',
#   '8 Years Of Total Black',
#   'Mantrasingen in Schöneberg',
#   'Collage - forum für frühe Musik | Adieu fortune - Abschied von Judy',
#   'FORTE KULTUR - Die Posaunen von Jericho',
#   'Queer Pop @800A',
#   'Frankies Party-Night   (Welcome Number 9)',
#   'Shiny Doom Phantasy',
#   "The Early Days • Indie-Party Like It's 200X • Berlin",
#   'Jochen Kowalski - „Enoch Arden“ von Richard Strauss und Lord Tennyson',
#   'Zenner Oktoberfest',
#   'Hot in Herre - November 2021',
#   'International Guitar Night',
#   'Ma Baker Party im Silverwings ✪✪✪ 80er 90er 2000er RnB House Charts Disco'],
#  ['intuitive medicine music - concert - Mitsch Kohn &amp; Sascha Alexander Vaymer',
#   'Sediments We Move',
#   'Satantango live',
#   'Duo Maoz / Poetzsch trifft Helter Skelter',
#   'LES BARBEAUX',
#   'Feierstarter Millennium',
#   'Jahreshauptversammlung 2021',
#   'Kesselhaus Winter Stage',
#   'LINA ALLEMANO + FRUIT OF THE LOOP | THE SOCIAL MUSIC SERIES // #PANDAJAZZ',
#   'Please Madame - Berlin',
#   'Thylacine  Album Release Konzert',
#   'Daniel Kahn &amp; Friends',
#   'Ways of Listening - Time Undisturbed',
#   'Voces x Ellas Konzert',
#   'Potsdam Tanzt!',
#   'Some Noise - Cover Rock',
#   'Popkulturkneipe goes Most Wanted: Music',
#   'Sunglasses @ Night - 80er Jahre Party in Velten - 30.10.2021',
#   'Madison Violet',
#   'Doc Schoko w/ Band (Support: Riches of the Poor)'],
#  ['Matrix Club Berlin. "Party Every Night" Sunday',
#   'GEST INVITES: 001',
#   'Latin &amp; Jazz Jam Session Alte Feuerwache',
#   'Ermäßigtes Ticket Jaimie Branch- fly or die II: bird dogs of paradise',
#   '29. Schlageralarm',
#   'Operetten zum Kaffee - Die Wiener Operette von Strauß bis Lehàr',
#   'Ben Ball - INSIDE OUT',
#   'Anneke Kim Sarnau &amp; Larsito - KINDERHILFE e.V. Benefiz am 29. Oktober 2021',
#   'Dornroses Rache - Moritaten',
#   'Picnic Player presents: "Lalangue"',
#   'Dinara Rasuleva &amp; Julia Vilianen // #PANDAwomen',
#   'EMPHA(SIS) - DEEP DANCE PARTY',
#   'Matrix "Party Every Night" Monday',
#   'CAMPUS AFFAIRS',
#   'NAVIBAND',
#   'WAHNSCHAFFE / GSCHLÖßL / FINK / RUPPNIG | THE SOCIAL MUSIC SERIES // #PANDA',
#   'Blueprint Band-Berlin -  BACK ON EARTH - Soul Jazz Blues Funk',
#   'Algiers | Berlin',
#   'The Ivory Boy at Bar Tausend',
#   'RANKEMANN Projekt - 2 Berliner Musiker, ein ganzes Universum'],
#  ['Heimat, Herz, Orte w/ Rolf Hansen @ Galerie Bernau',
#   'Ed Longo at Bar Tausend',
#   'Brennero at Bar Tausend',
#   'Eleven - Fusion Jazz / Pop',
#   'Muckemacher im Milchsalon',
#   'The Düsseldorf Düsterboys. Nenn mich Musik Tour',
#   'Rezital  Marina Goshkieva',
#   'DRIVE.live - Die Volkswagen Networking-Lounge',
#   'Brazilian Jazz Music / Adriano Trindade',
#   'Weihnachtssingen im Kiez',
#   'Richards Kindermusikladen im Milchsalon',
#   'Butterwegge Trio "Swaggernauten" Tour 2021 - BERLIN',
#   'LIGNIN’ WITH CHRIS HILL | THE SOCIAL MUSIC SERIES // #PANDAJAZZ',
#   'HALLOWEEN im WASCHHAUS',
#   'Schwester Cordula liebt Heimatromane - unsern Bub, den kriegst du net!',
#   'Lisa Canny &amp; Band',
#   'Stefanie Simon &amp; Henry de Winter',
#   'fem concerts presents Agnes Verano + Marlena Käthe',
#   'Schwarzblonde Weihnacht',
#   'Johannes Brahms: Ein Deutsches Requiem Op. 45'],
#  ['Dirty Dancing Party',
#   'Fucked Up! Party',
#   'PINK TURNS BLUE',
#   'Ladys Night by Tyra Knoxx',
#   'HENGE',
#   "MARC RIBOT'S CERAMIC DOG",
#   'HANGOVER - DIE XXL HOMEPARTY',
#   'POEMS FOR LAILA | Berlin',
#   'Opera Co-Pro Masterclass &amp; Auditions - Berlin 2021',
#   'Ma Baker Party im Silverwings ✪✪ 80er 90er 2000er RnB House Charts Disco',
#   'Chaosbay + Sentryturn // Cassiopeia, Berlin',
#   'Phileas+Flinte+Von Flocken',
#   'DON BYRON - ARUÁN ORTIZ DUO + VOLKER JAEKEL SOLO',
#   'Ermäßigter Eintritt für DON BYRON - ARUÁN ORTIZ DUO + VOLKER JAEKEL SOLO',
#   '36. Berliner Jazztreff',
#   "The Reverend Peyton's Big Damn Band",
#   'Ermäßigte Ticket für IN HONOR OF STEVE LACY',
#   'IN HONOR OF STEVE LACY',
#   'Austin Lucas',
#   'RADAU! im Milchsalon'],
#  ['Ermäßigter Eintritt KlangWorte - Jazz trifft auf Literatur',
#   "Ermäßigter Eintritt für MARC RIBOT'S CERAMIC DOG",
#   'HISS – 25 Jahre Jubiläumskonzert',
#   'Bizarre Music Festival',
#   'Operetten zum Kaffee - Weihnachten mit Alenka &amp; Frank',
#   '32. Mantrakonzert auf Spendenbasis am 18. Dezember 2021',
#   'KAKAOPHONIE',
#   'KlangWorte - Jazz trifft auf Literatur mit Laura Robles &amp; Camina',
#   'Ermäßigter Eintritt für RALPH TOWNER SOLO',
#   'RALPH TOWNER SOLO',
#   'Pietro Lombardi &amp; Band',
#   'Cattu der Traumfänger - Eine rote Zipfelmütze',
#   'Café del Mundo - „guitarize the world"',
#   'TOLYQYN',
#   '8. Berliner Chorleiter*innentag',
#   'Opossum Fest 2021 - Finest Heavy Underground',
#   'ELoA in Concert - Sarah Connor Cover',
#   'FARBGEFÜHLE FESTIVAL BERLIN 2021',
#   'Drum Klub',
#   'Bones (TeamSESH, USA) in Berlin'],
#  ['Jan Plewka singt Ton Steine Scherben &amp; Rio Reiser II',
#   'MAYBESHEWILL',
#   'Original Pflaumenbaum Revival Party X.',
#   'DARK BLUE ORCHESTRA (F) - Rock, Folk &amp; Alternative / Paris',
#   'The Düsseldorf Düsterboys',
#   'Estikay l Blueberry Boyz Tour l Berlin',
#   'Lauren Ruth Ward',
#   'Tequila &amp; The Sunrise Gang - Berlin',
#   'PESTILENCE - TESTIMONY OF THE ANCIENTS - 30th Anniversary Tour • Berlin',
#   'Downfall Of Gaia &amp; Implore | Berlin, cassiopeia',
#   'Todsünde/Weber&amp;Knechte/68FL:OZ',
#   'intuitive medicine music concert - Mitsch Kohn &amp; Sascha Alexander Vaymer',
#   'X-MAS - Sunglasses @ Night - 80er Jahre Party in Velten - 18.12.2021',
#   'Jarl/Herbstnebel /Sageras/Adversarius',
#   'Skating Polly',
#   'ROSALIE CUNNINGHAM (Purson) • Berlin',
#   'M. Walking On The Water',
#   'Betzefer • cassiopeia • Berlin',
#   '3.The Dark Paths Festival Warm Up',
#   'Scala &amp; Kolacny Brothers Live 2022'],
#  ['SpoWi Bad (or) Taste Party',
#   'Northern Lite - Ich sage JA Tour - Strandbad Babelsberg',
#   'Meadows - Berlin',
#   'ONE EYE OPEN',
#   'Seth Lakeman',
#   'THE TEENS -Core- LIVE! + Aftershowparty',
#   '3.The Dark Paths Festival',
#   'Motörhead Tribute mit Motörblast, Nitrogods und Volter',
#   'Mike &amp; The Moonpies',
#   'RED VIP EXPERIENCE - Berlin, Germany',
#   'Reggaeville Easter Special in Berlin 2022',
#   'Forced To Mode',
#   'UND WIEDER OKTOBER &amp; JANTE - CLUB-TOUR 2022',
#   'The Bland • Berlin (Privatclub)',
#   'Tré Burt',
#   'Christopher Paul Stelling',
#   'Ermäßigter Eintritt für LIEBMAN/ BRECKER/ COPLAND QUINTET',
#   'LIEBMAN/ BRECKER/ COPLAND QUINTET featuring DREW GRESS and JOEY BARON',
#   'The Sweet Serenades • Berlin (Badehaus)',
#   'SPIDERS &amp; HOT BREATH • Berlin Urban Spree'],
#  ["Daniel Romano's Outfit",
#   'Kyles Tolone - Berlin',
#   "Turbo AC's • cassiopeia • Berlin",
#   'Ljodahått',
#   'TOCOTRONIC',
#   'Nick &amp; June',
#   'Say Yes Dog',
#   'BLOND - MARTINI SPRITE 2021',
#   'Quadro Nuevo',
#   'Das Lumpenpack - OPEN AIR',
#   'SCHALKO | Bar BoBu',
#   "Django's Music - Filippo Dall'Asta &amp; Guests + Gypsy Jazz Jam Session!",
#   'Balladenabend mit Inna und Günther Wurell',
#   'Shirley Brill and Jonathan Aner',
#   'Big Meeting',
#   'Colours of Now - An Immersive classical concert in 4DSOUND',
#   'Okinawa Musik Live',
#   'Framed #61 - Jake Sherman',
#   'DÄTCHA MANDALA • Berlin',
#   'Filmmusik-Dinner-Show, The Lakeside Burghotel zu Strausberg'],
#  ['Die Mega 90/2000er Party',
#   'Berlin Classic Festival 2021 -06.11.21 - cancelt',
#   'Niek Baar &amp; Ben Kim // Violine &amp; Klavier',
#   'Grünauer Blues Bühne Nr.1',
#   'Maria Hartmann // Schauspielerin &amp; Irina Kolesnikova // Klavier',
#   'The All Night Open Mic and Jam Session!',
#   'Hi-Rez | Badehaus, Berlin',
#   'Moves  Johnson and The Boxhoppers live at Bar Bobu Berlin',
#   'The Rock n Roll Wrestling Bash Berlin',
#   'Unter meinem Bett 5 im Milchsalon. Ersatzkonzert vom 15.03.',
#   'ANTHONY B. Earth Day Bash - BERLIN',
#   'Devil Dance Festival &amp; Artchi´s B-Day',
#   'El Caribefunk (Colombia) in Berlin - RESCHEDULED 2022',
#   'JPson',
#   'HdO Club Party',
#   'Mixtape - Alternative 90s',
#   '30.Motorcycle Jamboree',
#   'Halli-Galli-Party in Templin',
#   'Sunglasses @ Night - 80er Jahre Party in Wittenberg - 23.04.2022',
#   'Halloween4our Schacht'],
#  ['EXTENSION - Silvester Edition',
#   'Weihnachtssingen im Gutshaus Pöthen - Das AntikGut',
#   'Queen Symphonic Tribute - 9.1.22 Magdeburg',
#   'Musical-Dinner-Show, Seehotel Plau am See',
#   'MARK FORSTER  Magdeburg -  Club-Tour 2022',
#   'Feuerengel - A Tribute to Rammstein',
#   'The Sweet Serenades • Weißwasser (Hafenstube)',
#   'Woodship, Kontraire &amp; Klangapart @ Kulturlounge, Leipzig',
#   'Grundeis',
#   'Schraubenyeti + Paula Peterssen Band - Konzert',
#   'Naven01 #1',
#   'Thatcher + For Next Time',
#   'The JEALS, NiJuSan, Klangapart',
#   'H25D // 02',
#   'Konzert mit dem Oslo String Quartet',
#   'KLANGPHONICS • Deep House. Live. • Leipzig',
#   'Neues bei Grieg! Gespräch und Konzert mit dem Geigenduo Gelland',
#   'Kätz - Nasty Noir - The Goth &amp; more Special Event',
#   'Kätz - Young Kinky Kitten - Dancehall &amp; House Music',
#   'Kätz - FUCKING BAD TASTE PARTY PART I'],
#  ['Kätz - FUCKING BAD TASTE PARTY PART II',
#   'Kätz - DIRTY CLUB MONSTER',
#   'Kätz - Black &amp; White Night - House- &amp; Blackmusic',
#   'Kätz - #CLUB M.A.S.K - DIE MASKENNACHT IM KÄTZ',
#   'Summer Dream Festival 2022',
#   'Elements of Elephants + Das Konvolut']]
